# %% [markdown]
# # 3. Reinforcement Learning from Human Feedback (RLHF)
# After training our binary classifier reward model, we are going to proceed into this preference alingment procedure by using this reward model to guide fine-tuning. Our end goal is to get the most pedantic version of the LLM we can possibly get. We
